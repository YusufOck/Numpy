# %%
import numpy as np

# %%
list = np.random.randint(0,5,(4,4))

# %%
list
# Out:
# array([[0, 3, 1, 0],
#        [4, 0, 2, 4],
#        [4, 4, 3, 0],
#        [4, 4, 4, 2]])

# %%
list2 = list.view()

# %%
list2
# Out:
# array([[0, 3, 1, 0],
#        [4, 0, 2, 4],
#        [4, 4, 3, 0],
#        [4, 4, 4, 2]])

# %%
list2[0]= [9,9,9,9]
list2
# Out:
# array([[9, 9, 9, 9],
#        [4, 0, 2, 4],
#        [4, 4, 3, 0],
#        [4, 4, 4, 2]])

# %%
list
# Out:
# array([[9, 9, 9, 9],
#        [4, 0, 2, 4],
#        [4, 4, 3, 0],
#        [4, 4, 4, 2]])

# %%
list3 = list2.copy()
list3
# Out:
# array([[9, 9, 9, 9],
#        [4, 0, 2, 4],
#        [4, 4, 3, 0],
#        [4, 4, 4, 2]])

# %%
list3[1] = [4,45,68,7]

# %%
list3
# Out:
# array([[ 9,  9,  9,  9],
#        [ 4, 45, 68,  7],
#        [ 4,  4,  3,  0],
#        [ 4,  4,  4,  2]])

# %%
list2
# Out:
# array([[9, 9, 9, 9],
#        [4, 0, 2, 4],
#        [4, 4, 3, 0],
#        [4, 4, 4, 2]])
