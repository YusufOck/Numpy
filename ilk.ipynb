# %%
import numpy as np

# %%
vector = np.array([1,2,3,4,5,6])

# %%
type(vector)
# Out:
# numpy.ndarray

# %%
vector.size
# Out:
# 6

# %%
vector = vector.astype("int64")
vector.dtype
# Out:
# dtype('int64')

# %%
vector = np.array([1,2,3,4,5], dtype = "int8")
vector.dtype
# Out:
# dtype('int8')

# %%
tarih = np.array(["2023-01-01"])
tarih.dtype
# Out:
# dtype('<U10')

# %%
tarih = tarih.astype("datetime64[ns]")
tarih.dtype
# Out:
# dtype('<M8[ns]')
